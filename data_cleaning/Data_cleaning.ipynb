# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.DataFrame(columns=["CODE_COLLEGE","COLLAGE_NAME"])

# %%
df=pd.read_csv("csv_preprocessing_2.csv")

# %%
df_co=df.copy()

# %%
df_co
# Out:
#       ID                                           Colleges  \
# 0   E001  University of Visvesvaraya College of Engineering
# 1   E001  University of Visvesvaraya College of Engineering
# 2   E001  University of Visvesvaraya College of Engineering
# 3   E001  University of Visvesvaraya College of Engineering
# 4   E001  University of Visvesvaraya College of Engineering
# 5   E001  University of Visvesvaraya College of Engineering
# 6   E002                S K S J T Institute of Engineering.
# 7   E002                S K S J T Institute of Engineering.
# 8   E002                S K S J T Institute of Engineering.
# 9   E003                       B M S College of Engineering
# 10  E003                       B M S College of Engineering
# 11  E003                       B M S College of Engineering
# 12  E003                       B M S College of Engineering
# 13  E004               Dr. Ambedkar Institute Of Technology
# 14  E004               Dr. Ambedkar Institute Of Technology
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df_co["Branch"]=encoder.fit_transform(df_co["Branch"])
df_co["ID"]=encoder.fit_transform(df_co["ID"])

# %%
df_co
# Out:
#     ID                                           Colleges  Branch  Min_Range
# 0    0  University of Visvesvaraya College of Engineering       0        160
# 1    0  University of Visvesvaraya College of Engineering       1         80
# 2    0  University of Visvesvaraya College of Engineering       2        150
# 3    0  University of Visvesvaraya College of Engineering       3        130
# 4    0  University of Visvesvaraya College of Engineering       4        100
# 5    0  University of Visvesvaraya College of Engineering       5        105
# 6    1                S K S J T Institute of Engineering.       1         80
# 7    1                S K S J T Institute of Engineering.       2        150
# 8    1                S K S J T Institute of Engineering.       3        130
# 9    2                       B M S College of Engineering       1         80
# 10   2                       B M S College of Engineering       3        130
# ...

# %%
x=df_co[['Branch','Min_Range']]
y=df_co['ID']

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((28, 2), (8, 2))

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict=rfc.predict(x_test)

# %%
from sklearn.metrics import classification_report,accuracy_score
accuracy_score(y_predict,y_test)
# Out:
# 0.125

# %%
print(classification_report(y_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         3
#            6       0.33      0.50      0.40         2
#
#     accuracy                           0.12         8
#    macro avg       0.06      0.08      0.07         8
# weighted avg       0.08      0.12      0.10         8

# %%
rfc.predict([[0,150]])
# Out:
# array([0])

# %%
from sklearn.linear_model import LogisticRegression
log_ref=LogisticRegression()
log_ref.fit(x,y)
# Out:
# LogisticRegression()

# %%
log_ref.predict([[0,150]])
# Out:
# array([5])

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
dtc.predict([[0,178]])
# Out:
# array([5])
